# %% [markdown]
# <a href="https://colab.research.google.com/github/pinheiroanifa5/Algoritmo-e-estruturas-de-dados-/blob/main/Eletric_Vehicle_population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# database

data_path= '/content/database/Electric_Vehicle_Population_Data.csv'
ev_data=pd.read_csv(data_path)

#visualizaçao Dataframe
ev_data.head()
# Out:
#    VIN (1-10)  County       City State  Postal Code  Model Year   Make  \
# 0  WBY8P6C58K    King    Seattle    WA      98115.0        2019    BMW
# 1  5YJSA1DN4D  Kitsap  Bremerton    WA      98312.0        2013  TESLA
# 2  5YJSA1E26J    King       Kent    WA      98042.0        2018  TESLA
# 3  WBY2Z2C54E    King   Bellevue    WA      98004.0        2014    BMW
# 4  5YJXCDE23J    King   Bellevue    WA      98004.0        2018  TESLA
#
#      Model                   Electric Vehicle Type  \
# 0       I3          Battery Electric Vehicle (BEV)
# 1  MODEL S          Battery Electric Vehicle (BEV)
# 2  MODEL S          Battery Electric Vehicle (BEV)
# 3       I8  Plug-in Hybrid Electric Vehicle (PHEV)
# 4  MODEL X          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             153
# 1           Clean Alternative Fuel Vehicle Eligible             208
# ...

# %%
ev_data.info() #dataset info

ev_data.describe() #dataset description

#tipos de veiculos eletricos

sns.countplot(x='Electric Vehicle Type',data=ev_data)
plt.title('Electric Vehicle Type')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73421 entries, 0 to 73420
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         73421 non-null  object
#  1   County                                             73420 non-null  object
#  2   City                                               73420 non-null  object
#  3   State                                              73421 non-null  object
#  4   Postal Code                                        73420 non-null  float64
#  5   Model Year                                         73421 non-null  int64
#  6   Make                                               73421 non-null  object
#  7   Model                                              73421 non-null  object
# ...

# %%
#tipo de veiculo eletrico por ano
plt.figure(figsize=(10, 6))
sns.countplot(x='Electric Vehicle Type', data=ev_data)
plt.title('Distribuição dos Tipos de Veículos Elétricos')
plt.xlabel('Tipo de Veículo Elétrico')
plt.ylabel('Contagem')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Distribuiçao por modelo de veiculo e por ano
plt.figure(figsize=(10, 6))
sns.histplot(ev_data['Model Year'], bins=20, kde=True)
plt.title('Distribuição dos Veículos por Ano do Modelo')
plt.xlabel('Ano do Modelo')
plt.ylabel('Contagem')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
